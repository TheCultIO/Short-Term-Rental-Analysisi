# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
from scipy.spatial.distance import cdist

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning

# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Suppress ConvergenceWarnings
warnings.simplefilter(action='ignore', category=ConvergenceWarning)

# %%
df= pd.read_csv('PUBLIC REMARKS INCLUDE STR LANGUAGE.csv', low_memory=False)

# %%
df.info(max_cols=180, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8254 entries, 0 to 8253
# Data columns (total 161 columns):
#  #    Column                                  Non-Null Count  Dtype
# ---   ------                                  --------------  -----
#  0    List Number                             8254 non-null   int64
#  1    Agency Name                             8254 non-null   object
#  2    Agency Phone                            8212 non-null   object
#  3    Listing Agent                           8254 non-null   object
#  4    Co-Listing Agent                        2327 non-null   object
#  5    Property Type                           8254 non-null   object
#  6    Card Format                             8254 non-null   object
#  7    Selling Agency                          4687 non-null   object
#  8    Selling Agent                           4687 non-null   object
#  9    Co-Selling Agent                        33 non-null     object
#  10   End Date                                0 non-null      float64
#  11   Dwelling Type                           8254 non-null   object
#  12   List Date                               8254 non-null   object
#  13   Close of Escrow Date                    4688 non-null   object
#  14   Under Contract Date                     5584 non-null   object
#  15   Fallthrough Date                        234 non-null    object
#  16   Status                                  8254 non-null   object
#  17   Status Change Date                      8254 non-null   object
#  18   Temp Off Market Date                    0 non-null      float64
#  19   Cancel Date                             0 non-null      float64
#  20   UCB or CCBS                             387 non-null    object
#  21   Original List Price                     8254 non-null   float64
#  22   List Price                              8254 non-null   float64
#  23   Sold Price                              4688 non-null   float64
#  24   Price/SqFt                              8239 non-null   float64
#  25   Map Code/Grid                           6585 non-null   object
#  26   House Number                            8254 non-null   object
#  27   Building Number                         206 non-null    object
#  28   Compass                                 8052 non-null   object
#  29   Street Name                             8254 non-null   object
#  30   Unit #                                  939 non-null    object
#  31   St Dir Sfx                              64 non-null     object
#  32   St Suffix                               8254 non-null   object
#  33   Sub Agent $/%                           87 non-null     object
#  34   City/Town Code                          8254 non-null   object
#  35   State/Province                          8254 non-null   object
#  36   County Code                             8254 non-null   object
#  37   Country                                 8254 non-null   object
#  38   Zip Code                                8254 non-null   int64
#  39   Geo Lat                                 8254 non-null   float64
#  40   Geo Lon                                 8254 non-null   float64
#  41   Approx SQFT                             8240 non-null   float64
#  42   Bedrooms Plus                           8253 non-null   float64
#  43   Year Built                              8254 non-null   int64
#  44   Buyer Broker $/%                        8239 non-null   object
#  45   Buyer/Broker                            8254 non-null   object
#  46   Subagents                               8254 non-null   object
#  47   Variable Commission                     8254 non-null   object
#  48   # Bedrooms                              8254 non-null   int64
#  49   # Bathrooms                             8254 non-null   float64
#  50   # of Interior Levels                    8254 non-null   int64
#  51   Exterior Stories                        8254 non-null   int64
#  52   Source Apx Lot SqFt                     8169 non-null   object
#  53   Pool                                    8254 non-null   object
#  54   Taxes                                   8247 non-null   float64
#  55   Tax Year                                8249 non-null   float64
#  56   Legal Description (Abbrev)              6962 non-null   object
#  57   Public Remarks                          8254 non-null   object
#  58   Assessor Number                         8253 non-null   object
#  59   Legal                                   0 non-null      float64
#  60   Directions                              7744 non-null   object
#  61   Ownr/Occ Name - DND2                    8243 non-null   object
#  62   Owner/Occ Phn - DND2                    1339 non-null   object
#  63   Marketing Name                          2722 non-null   object
#  64   Builder Name                            8148 non-null   object
#  65   mod_timestamp                           8254 non-null   object
#  66   Assessor Parcel Ltr                     858 non-null    object
#  67   Out of Area Schl Dst                    90 non-null     object
#  68   Source of SqFt                          8254 non-null   object
#  69   Tax Municipality                        8253 non-null   object
#  70   Auction                                 8253 non-null   object
#  71   Horses                                  8254 non-null   object
#  72   Ownership                               8254 non-null   object
#  73   Hundred Block                           2516 non-null   object
#  74   Type                                    8254 non-null   object
#  75   Elementary School                       8254 non-null   object
#  76   Jr. High School                         8254 non-null   object
#  77   High School                             8254 non-null   object
#  78   Model                                   2348 non-null   object
#  79   Hndrd Blk Directionl                    2572 non-null   object
#  80   Zip4                                    6585 non-null   float64
#  81   Week Avail Timeshare                    170 non-null    float64
#  82   Comp to Subagent                        4352 non-null   float64
#  83   Comp to Buyer Broker                    8241 non-null   float64
#  84   Other Compensation                      265 non-null    float64
#  85   Guest House SqFt                        370 non-null    float64
#  86   Approx Lot SqFt                         8253 non-null   float64
#  87   Assessor's Book #                       8254 non-null   float64
#  88   Assessor's Map #                        8254 non-null   float64
#  89   Assessor's Parcel #                     8254 non-null   float64
#  90   Off Market Date                         5584 non-null   object
#  91   Cross Street                            7977 non-null   object
#  92   Subdivision                             8210 non-null   object
#  93   Dwelling Styles                         8169 non-null   object
#  94   Flood Zone                              1332 non-null   object
#  95   Approx Lot Acres                        3625 non-null   float64
#  96   On Market Date                          1021 non-null   object
#  97   Lead Based Hazard Disclosure            613 non-null    object
#  98   Showing Service                         0 non-null      float64
#  99   Co-Ownership (Fractional) Agreement YN  2591 non-null   object
#  100  Photo URL                               8242 non-null   object
#  101  Days on Market                          8254 non-null   int64
#  102  Rooms                                   1259 non-null   object
#  103  Features                                8254 non-null   object
#  104  Unnamed: 104                            1 non-null      object
#  105  Unnamed: 105                            1 non-null      object
#  106  Unnamed: 106                            1 non-null      object
#  107  Unnamed: 107                            0 non-null      float64
#  108  Unnamed: 108                            1 non-null      object
#  109  Unnamed: 109                            1 non-null      object
#  110  Unnamed: 110                            1 non-null      object
#  111  Unnamed: 111                            1 non-null      object
#  112  Unnamed: 112                            0 non-null      float64
#  113  Unnamed: 113                            0 non-null      float64
#  114  Unnamed: 114                            1 non-null      object
#  115  Unnamed: 115                            1 non-null      object
#  116  Unnamed: 116                            1 non-null      object
#  117  Unnamed: 117                            1 non-null      object
#  118  Unnamed: 118                            0 non-null      float64
#  119  Unnamed: 119                            1 non-null      object
#  120  Unnamed: 120                            1 non-null      object
#  121  Unnamed: 121                            0 non-null      float64
#  122  Unnamed: 122                            0 non-null      float64
#  123  Unnamed: 123                            0 non-null      float64
#  124  Unnamed: 124                            1 non-null      float64
#  125  Unnamed: 125                            1 non-null      float64
#  126  Unnamed: 126                            1 non-null      float64
#  127  Unnamed: 127                            1 non-null      float64
#  128  Unnamed: 128                            1 non-null      object
#  129  Unnamed: 129                            1 non-null      float64
#  130  Unnamed: 130                            0 non-null      float64
#  131  Unnamed: 131                            1 non-null      object
#  132  Unnamed: 132                            1 non-null      object
#  133  Unnamed: 133                            0 non-null      float64
#  134  Unnamed: 134                            0 non-null      float64
#  135  Unnamed: 135                            1 non-null      object
#  136  Unnamed: 136                            0 non-null      float64
#  137  Unnamed: 137                            1 non-null      object
#  138  Unnamed: 138                            1 non-null      object
#  139  Unnamed: 139                            1 non-null      object
#  140  Unnamed: 140                            1 non-null      object
#  141  Unnamed: 141                            1 non-null      float64
#  142  Unnamed: 142                            1 non-null      float64
#  143  Unnamed: 143                            1 non-null      float64
#  144  Unnamed: 144                            1 non-null      float64
#  145  Unnamed: 145                            1 non-null      float64
#  146  Unnamed: 146                            1 non-null      float64
#  147  Unnamed: 147                            1 non-null      object
#  148  Unnamed: 148                            1 non-null      object
#  149  Unnamed: 149                            1 non-null      object
#  150  Unnamed: 150                            1 non-null      object
#  151  Unnamed: 151                            1 non-null      float64
#  152  Unnamed: 152                            1 non-null      float64
#  153  Unnamed: 153                            1 non-null      float64
#  154  Unnamed: 154                            1 non-null      float64
#  155  Unnamed: 155                            1 non-null      object
#  156  Unnamed: 156                            1 non-null      object
#  157  Unnamed: 157                            1 non-null      float64
#  158  Unnamed: 158                            1 non-null      float64
#  159  Unnamed: 159                            1 non-null      object
#  160  Unnamed: 160                            1 non-null      object
# dtypes: float64(55), int64(7), object(99)
# memory usage: 10.1+ MB

# %%
df = df.drop_duplicates()
df1=df.copy()

# %%
def drop_columns_with_high_null(df, threshold=0.75):
    null_percentages = df.isnull().mean()
    columns_to_drop = null_percentages[null_percentages > threshold].index
    df = df.drop(columns=columns_to_drop)
    return df

# %%
df=drop_columns_with_high_null(df, threshold=0.67)

# %%
df.isnull().sum().sort_values()
# Out:
# List Number                0
# Geo Lat                    0
# Geo Lon                    0
# Year Built                 0
# Buyer/Broker               0
#                         ...
# Close of Escrow Date    3566
# Selling Agency          3567
# Selling Agent           3567
# Comp to Subagent        3902
# Approx Lot Acres        4629
# Length: 76, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8254 entries, 0 to 8253
# Data columns (total 76 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   List Number                 8254 non-null   int64
#  1   Agency Name                 8254 non-null   object
#  2   Agency Phone                8212 non-null   object
#  3   Listing Agent               8254 non-null   object
#  4   Property Type               8254 non-null   object
#  5   Card Format                 8254 non-null   object
#  6   Selling Agency              4687 non-null   object
#  7   Selling Agent               4687 non-null   object
#  8   Dwelling Type               8254 non-null   object
#  9   List Date                   8254 non-null   object
#  10  Close of Escrow Date        4688 non-null   object
#  11  Under Contract Date         5584 non-null   object
#  12  Status                      8254 non-null   object
#  13  Status Change Date          8254 non-null   object
#  14  Original List Price         8254 non-null   float64
#  15  List Price                  8254 non-null   float64
#  16  Sold Price                  4688 non-null   float64
#  17  Price/SqFt                  8239 non-null   float64
#  18  Map Code/Grid               6585 non-null   object
#  19  House Number                8254 non-null   object
#  20  Compass                     8052 non-null   object
#  21  Street Name                 8254 non-null   object
#  22  St Suffix                   8254 non-null   object
#  23  City/Town Code              8254 non-null   object
#  24  State/Province              8254 non-null   object
#  25  County Code                 8254 non-null   object
#  26  Country                     8254 non-null   object
#  27  Zip Code                    8254 non-null   int64
#  28  Geo Lat                     8254 non-null   float64
#  29  Geo Lon                     8254 non-null   float64
#  30  Approx SQFT                 8240 non-null   float64
#  31  Bedrooms Plus               8253 non-null   float64
#  32  Year Built                  8254 non-null   int64
#  33  Buyer Broker $/%            8239 non-null   object
#  34  Buyer/Broker                8254 non-null   object
#  35  Subagents                   8254 non-null   object
#  36  Variable Commission         8254 non-null   object
#  37  # Bedrooms                  8254 non-null   int64
#  38  # Bathrooms                 8254 non-null   float64
#  39  # of Interior Levels        8254 non-null   int64
#  40  Exterior Stories            8254 non-null   int64
#  41  Source Apx Lot SqFt         8169 non-null   object
#  42  Pool                        8254 non-null   object
#  43  Taxes                       8247 non-null   float64
#  44  Tax Year                    8249 non-null   float64
#  45  Legal Description (Abbrev)  6962 non-null   object
#  46  Public Remarks              8254 non-null   object
#  47  Assessor Number             8253 non-null   object
#  48  Directions                  7744 non-null   object
#  49  Ownr/Occ Name - DND2        8243 non-null   object
#  50  Builder Name                8148 non-null   object
#  51  mod_timestamp               8254 non-null   object
#  52  Source of SqFt              8254 non-null   object
#  53  Tax Municipality            8253 non-null   object
#  54  Auction                     8253 non-null   object
#  55  Horses                      8254 non-null   object
#  56  Ownership                   8254 non-null   object
#  57  Type                        8254 non-null   object
#  58  Elementary School           8254 non-null   object
#  59  Jr. High School             8254 non-null   object
#  60  High School                 8254 non-null   object
#  61  Zip4                        6585 non-null   float64
#  62  Comp to Subagent            4352 non-null   float64
#  63  Comp to Buyer Broker        8241 non-null   float64
#  64  Approx Lot SqFt             8253 non-null   float64
#  65  Assessor's Book #           8254 non-null   float64
#  66  Assessor's Map #            8254 non-null   float64
#  67  Assessor's Parcel #         8254 non-null   float64
#  68  Off Market Date             5584 non-null   object
#  69  Cross Street                7977 non-null   object
#  70  Subdivision                 8210 non-null   object
#  71  Dwelling Styles             8169 non-null   object
#  72  Approx Lot Acres            3625 non-null   float64
#  73  Photo URL                   8242 non-null   object
#  74  Days on Market              8254 non-null   int64
#  75  Features                    8254 non-null   object
# dtypes: float64(19), int64(7), object(50)
# memory usage: 4.8+ MB

# %%
df.describe(include="all").T
# Out:
#                    count unique  \
# List Number       8254.0    NaN
# Agency Name         8254   1502
# Agency Phone        8212   1352
# Listing Agent       8254   4890
# Property Type       8254      1
# ...                  ...    ...
# Dwelling Styles     8169      3
# Approx Lot Acres  3625.0    NaN
# Photo URL           8242   8242
# Days on Market    8254.0    NaN
# Features            8254   8248
#
#                                                                 top  freq  \
# List Number                                                     NaN   NaN
# Agency Name                                      HomeSmart (cril01)   191
# Agency Phone                                         (602) 230-7600   493
# Listing Agent                                        Ashley Pickens   136
# Property Type                                           Residential  8254
# ...                                                             ...   ...
# Dwelling Styles                                            Detached  7027
# Approx Lot Acres                                                NaN   NaN
# Photo URL         http://cdn.photos.sparkplatform.com/az/2023082...     1
# Days on Market                                                  NaN   NaN
# Features          Association & Fees|HOA Paid Frequency|Quarterl...     2
#
#                             mean            std        min        25%  \
# List Number       5737130.944996  738313.967584  2584621.0  5061433.5
# Agency Name                  NaN            NaN        NaN        NaN
# Agency Phone                 NaN            NaN        NaN        NaN
# Listing Agent                NaN            NaN        NaN        NaN
# Property Type                NaN            NaN        NaN        NaN
# ...                          ...            ...        ...        ...
# Dwelling Styles              NaN            NaN        NaN        NaN
# Approx Lot Acres        1.890366      32.550135        0.0      0.124
# Photo URL                    NaN            NaN        NaN        NaN
# Days on Market         77.808941      98.565867        0.0       19.0
# Features                     NaN            NaN        NaN        NaN
#
#                         50%        75%        max
# List Number       5109077.5  6574456.5  6603510.0
# Agency Name             NaN        NaN        NaN
# Agency Phone            NaN        NaN        NaN
# Listing Agent           NaN        NaN        NaN
# Property Type           NaN        NaN        NaN
# ...                     ...        ...        ...
# Dwelling Styles         NaN        NaN        NaN
# Approx Lot Acres      0.171      0.358     1739.0
# Photo URL               NaN        NaN        NaN
# Days on Market         47.0      102.0     1627.0
# Features                NaN        NaN        NaN
#
# [76 rows x 11 columns]

# %%
constant_columns = [col for col in df.columns if df[col].nunique() == 1]

# Printing the list of constant columns
print("Columns with constant value:", constant_columns)
# Out:
# Columns with constant value: ['Property Type', 'Card Format']

# %% [markdown]
# ### These columns ['Property Type', 'Card Format'] are all RESIDENTIAL properties, sio droppping them for better Data Handlbng

# %%
df.drop('Property Type',axis=1, inplace= True )
df.drop('Card Format',axis=1, inplace= True )

# %%
df['Public Remarks']
# Out:
# 0       Discover the perfect blend of comfort, conveni...
# 1       THIS IS YOUR NEXT HOME! Move-In Ready, and rar...
# 2       Comfortable and stylish living space awaits yo...
# 3       1+ACRE property in desirable Huachuca Mountain...
# 4       This extremely sought-after, newly constructed...
#                               ...
# 8249    Original owner selling energy efficient home w...
# 8250    Unique 3 bedroom 2 bath home on 3.42 acres of ...
# 8251    Maracay Single Level home in the highly desira...
# 8252    This gorgeous new home features  granite kitch...
# 8253    Beautiful new single level home located in the...
# Name: Public Remarks, Length: 8254, dtype: object

# %%
# Creating a boolean mask for each word pattern we're interested in
mask_str = df['Public Remarks'].str.contains(r'\bstr\b', case=False, na=False, regex=True)
mask_short_term_rental = df['Public Remarks'].str.contains(r'\bshort term rental\b', case=False, na=False, regex=True)
mask_vacation_rental = df['Public Remarks'].str.contains(r'\bVacation rental\b', case=False, na=False, regex=True)

# %%
mask_str.sum()
# Out:
# 22

# %%
mask_short_term_rental.sum()
# Out:
# 72

# %%
mask_vacation_rental.sum()
# Out:
# 97

# %%
# Combining these masks with 'or' (|)
final_mask = mask_str | mask_short_term_rental | mask_vacation_rental

# Filtering the DataFrame based on the final mask
filtered_df = df[final_mask]

filtered_df
# Out:
#       List Number                                   Agency Name  \
# 54        6575418                        RE/MAX Sedona (rmxs01)
# 63        6567648                            NORTH&CO. (nrtc01)
# 80        6579707  Keller Williams Realty East Valley (kwevt01)
# 81        6582692                            NORTH&CO. (nrtc01)
# 85        6587878             Arizona Elite Properties (ROCK16)
# ...           ...                                           ...
# 7130      5045673                    Realty Executives (reax09)
# 7133      5110883             Sandra Wilken Properties (swlp01)
# 7281      5104609                            HomeSmart (cril10)
# 8185      5110725       Southwest Preferred Properties (swpp01)
# 8216      5124612            Century 21 Desert Estates (ctde01)
#
#         Agency Phone       Listing Agent  \
# 54    (928) 282-4166           Roy Grimm
# 63    (602) 714-7000          Liza Czopp
# 80    (480) 839-6600    Leonard Saavedra
# 81    (602) 714-7000     Sheryl Matuszak
# 85    (928) 476-2973         Evelyn Beck
# ...              ...                 ...
# 7130  (480) 948-9450     J. Garry Folino
# 7133  (480) 596-0001         Gregg Hayes
# 7281  (602) 230-7600  Andrea Ann Loukota
# 8185  (602) 266-0500         Susan E Fix
# 8216  (623) 742-6994           Kay Jenne
#
#                                Selling Agency    Selling Agent  \
# 54                                        NaN              NaN
# 63                                        NaN              NaN
# 80                                        NaN              NaN
# 81                                        NaN              NaN
# 85                                        NaN              NaN
# ...                                       ...              ...
# 7130            RE/MAX Professionals (rmxi02)       Mary Groff
# 7133        Sandra Wilken Properties (swlp01)      Gregg Hayes
# 7281             US Preferred Realty (uspr07)  Alex Rabinovich
# 8185  Southwest Preferred Properties (swpp01)      Susan E Fix
# 8216                Realty ONE Group (reog03)       Brad Speck
#
#                  Dwelling Type   List Date Close of Escrow Date  \
# 54    Single Family - Detached  2023-06-30                  NaN
# 63                   Townhouse  2023-06-07                  NaN
# 80    Single Family - Detached  2023-07-06                  NaN
# 81    Single Family - Detached  2023-07-20                  NaN
# 85    Single Family - Detached  2023-08-03                  NaN
# ...                        ...         ...                  ...
# 7130      Apartment Style/Flat  2013-12-24           2014-05-30
# 7133  Single Family - Detached  2014-05-05           2014-05-30
# 7281                 Townhouse  2014-04-23           2014-06-02
# 8185  Single Family - Detached  2014-05-05           2014-06-27
# 8216  Single Family - Detached  2014-06-02           2014-06-24
#
#      Under Contract Date  ... Assessor's Map # Assessor's Parcel #  \
# 54                   NaN  ...             44.0                 8.0
# 63                   NaN  ...             36.0                25.0
# 80                   NaN  ...              8.0                72.0
# 81                   NaN  ...              7.0                 9.0
# 85                   NaN  ...             69.0               208.0
# ...                  ...  ...              ...                 ...
# 7130          2014-05-11  ...             73.0               660.0
# 7133          2014-05-05  ...             27.0                44.0
# 7281          2014-05-02  ...             25.0                74.0
# 8185          2014-05-19  ...             87.0                16.0
# 8216          2014-06-05  ...             60.0               617.0
#
#       Off Market Date                                 Cross Street  \
# 54                NaN                        Bristlecone Pines Rd.
# 63                NaN                Scottsdale Road and Camelback
# 80                NaN  From HWY 87 ( Beeline Hwy ) and W.Wade Lane
# 81                NaN                          Cactus and 58th Way
# 85                NaN                Hwy. 87 & Anasazi in Pine, AZ
# ...               ...                                          ...
# 7130       2014-05-30                       92ND STREET & RAINTREE
# 7133       2014-05-30                   Lincoln Drive & 52nd Place
# 7281       2014-05-31                              Hayden & Thomas
# 8185       2014-05-24      EXIT 126 N TO PEBBLECREEK ENTRANCE,LEFT
# 8216       2014-06-06                      Thunderbird and Boswell
#
#                       Subdivision  Dwelling Styles Approx Lot Acres  \
# 54                      Las Lomas         Detached            0.861
# 63               COLONY CAMELBACK         Attached            0.001
# 80                 PAYSON HEIGHTS         Detached            0.239
# 81                 AVANT 1 UNIT 4         Detached            0.415
# 85           Woodshire at Elk Rim         Detached            0.137
# ...                           ...              ...              ...
# 7130                  THE ALLISON          Stacked              NaN
# 7133  MacDonald Acres - Exception         Detached              NaN
# 7281            Scottsdale Villas         Attached              NaN
# 8185           PEBBLECREEK UNIT 9         Detached              NaN
# 8216            Sun City Unit 25A         Detached              NaN
#
#                                               Photo URL Days on Market  \
# 54    http://cdn.photos.sparkplatform.com/az/2023051...             72
# 63    http://cdn.photos.sparkplatform.com/az/2023061...             91
# 80    http://cdn.photos.sparkplatform.com/az/2023070...             62
# 81    http://cdn.photos.sparkplatform.com/az/2023071...             52
# 85    http://cdn.photos.sparkplatform.com/az/2023080...             38
# ...                                                 ...            ...
# 7130  http://cdn.photos.sparkplatform.com/az/2013122...            157
# 7133  http://cdn.photos.sparkplatform.com/az/2014042...             25
# 7281  http://cdn.photos.sparkplatform.com/az/2014042...             38
# 8185  http://cdn.photos.sparkplatform.com/az/2014020...             19
# 8216  http://cdn.photos.sparkplatform.com/az/2014060...              4
#
#                                                Features
# 54    Association & Fees|HOA Y/N|N;Association & Fee...
# 63    Association & Fees|HOA Paid Frequency|Monthly;...
# 80    Association & Fees|HOA Y/N|N;Items Updated|Flo...
# 81    Association & Fees|HOA Y/N|N;Items Updated|Poo...
# 85    Association & Fees|HOA Paid Frequency|Quarterl...
# ...                                                 ...
# 7130  Association & Fees|HOA Paid Frequency|Monthly;...
# 7133  Association & Fees|Rec Center Fee Y/N|N;Associ...
# 7281  Association & Fees|HOA Paid Frequency|Monthly;...
# 8185  Association & Fees|HOA Paid Frequency|Semi-Ann...
# 8216  Association & Fees|HOA Paid Frequency|Annually...
#
# [184 rows x 74 columns]

# %%
filtered_df['Public Remarks']
# Out:
# 54      Flagship luxury Vacation Rental property.  Tur...
# 63      LOCATION, LOCATION!! This beautifully remodele...
# 80      COMPLETELY REMODELED & PERMITTED, Move in read...
# 81      Modern, 5 bedrooms, 3 baths remodeled and full...
# 85      Come see this Beautiful Country-Modern Home in...
#                               ...
# 7130    ONE OF THE MOST POPULAR COMPLEXES IN N.SCOTTSD...
# 7133    EXCEPTIONAL PARADISE VALLEY LOCATION!   MAGNIF...
# 7281    Don't miss out on this well priced townhouse i...
# 8185    This fantastic buy includes everything!  All t...
# 8216    Almost 1/4 acre corner lot one street from gol...
# Name: Public Remarks, Length: 184, dtype: object

# %% [markdown]
# ## Comments :
# ### * There are some inputs like STR - No , etc which is also included in this filtered_df which needed to be handled.
# ### * So we have around only 150 rows/input  in the final dataframe among 8000+ rows

# %%
x=df1[df1['City/Town Code']=='Phoenix']

# %%
x['City/Town Code']
# Out:
# 2       Phoenix
# 9       Phoenix
# 12      Phoenix
# 13      Phoenix
# 17      Phoenix
#          ...
# 8234    Phoenix
# 8235    Phoenix
# 8238    Phoenix
# 8241    Phoenix
# 8249    Phoenix
# Name: City/Town Code, Length: 1990, dtype: object

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1990 entries, 2 to 8249
# Columns: 161 entries, List Number to Unnamed: 160
# dtypes: float64(55), int64(7), object(99)
# memory usage: 2.5+ MB

# %%
x=drop_columns_with_high_null(df, threshold=0.98)

# %% [markdown]
# ### We have 1990 entries in Phoenix

# %%
x.rename(columns={'Geo Lat': 'Latitude'}, inplace=True)
x.rename(columns={'Geo Lon': 'Longitude'}, inplace=True)
x.rename(columns={'# Bedrooms': 'Bedrooms'}, inplace=True)

# %%
x.info(max_cols=180, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8254 entries, 0 to 8253
# Data columns (total 74 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   List Number                 8254 non-null   int64
#  1   Agency Name                 8254 non-null   object
#  2   Agency Phone                8212 non-null   object
#  3   Listing Agent               8254 non-null   object
#  4   Selling Agency              4687 non-null   object
#  5   Selling Agent               4687 non-null   object
#  6   Dwelling Type               8254 non-null   object
#  7   List Date                   8254 non-null   object
#  8   Close of Escrow Date        4688 non-null   object
#  9   Under Contract Date         5584 non-null   object
#  10  Status                      8254 non-null   object
#  11  Status Change Date          8254 non-null   object
#  12  Original List Price         8254 non-null   float64
#  13  List Price                  8254 non-null   float64
#  14  Sold Price                  4688 non-null   float64
#  15  Price/SqFt                  8239 non-null   float64
#  16  Map Code/Grid               6585 non-null   object
#  17  House Number                8254 non-null   object
#  18  Compass                     8052 non-null   object
#  19  Street Name                 8254 non-null   object
#  20  St Suffix                   8254 non-null   object
#  21  City/Town Code              8254 non-null   object
#  22  State/Province              8254 non-null   object
#  23  County Code                 8254 non-null   object
#  24  Country                     8254 non-null   object
#  25  Zip Code                    8254 non-null   int64
#  26  Latitude                    8254 non-null   float64
#  27  Longitude                   8254 non-null   float64
#  28  Approx SQFT                 8240 non-null   float64
#  29  Bedrooms Plus               8253 non-null   float64
#  30  Year Built                  8254 non-null   int64
#  31  Buyer Broker $/%            8239 non-null   object
#  32  Buyer/Broker                8254 non-null   object
#  33  Subagents                   8254 non-null   object
#  34  Variable Commission         8254 non-null   object
#  35  Bedrooms                    8254 non-null   int64
#  36  # Bathrooms                 8254 non-null   float64
#  37  # of Interior Levels        8254 non-null   int64
#  38  Exterior Stories            8254 non-null   int64
#  39  Source Apx Lot SqFt         8169 non-null   object
#  40  Pool                        8254 non-null   object
#  41  Taxes                       8247 non-null   float64
#  42  Tax Year                    8249 non-null   float64
#  43  Legal Description (Abbrev)  6962 non-null   object
#  44  Public Remarks              8254 non-null   object
#  45  Assessor Number             8253 non-null   object
#  46  Directions                  7744 non-null   object
#  47  Ownr/Occ Name - DND2        8243 non-null   object
#  48  Builder Name                8148 non-null   object
#  49  mod_timestamp               8254 non-null   object
#  50  Source of SqFt              8254 non-null   object
#  51  Tax Municipality            8253 non-null   object
#  52  Auction                     8253 non-null   object
#  53  Horses                      8254 non-null   object
#  54  Ownership                   8254 non-null   object
#  55  Type                        8254 non-null   object
#  56  Elementary School           8254 non-null   object
#  57  Jr. High School             8254 non-null   object
#  58  High School                 8254 non-null   object
#  59  Zip4                        6585 non-null   float64
#  60  Comp to Subagent            4352 non-null   float64
#  61  Comp to Buyer Broker        8241 non-null   float64
#  62  Approx Lot SqFt             8253 non-null   float64
#  63  Assessor's Book #           8254 non-null   float64
#  64  Assessor's Map #            8254 non-null   float64
#  65  Assessor's Parcel #         8254 non-null   float64
#  66  Off Market Date             5584 non-null   object
#  67  Cross Street                7977 non-null   object
#  68  Subdivision                 8210 non-null   object
#  69  Dwelling Styles             8169 non-null   object
#  70  Approx Lot Acres            3625 non-null   float64
#  71  Photo URL                   8242 non-null   object
#  72  Days on Market              8254 non-null   int64
#  73  Features                    8254 non-null   object
# dtypes: float64(19), int64(7), object(48)
# memory usage: 4.7+ MB

# %%
df2= pd.read_csv('Phoenix_data_USD (1).csv', low_memory=False)

# %%
df2.info(max_cols=180, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7035 entries, 0 to 7034
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Listing URL             7035 non-null   object
#  1   Property Type           7035 non-null   object
#  2   Latitude                7035 non-null   float64
#  3   Longitude               7035 non-null   float64
#  4   Star Rating             7035 non-null   float64
#  5   Number of Active Days   7035 non-null   int64
#  6   Bedrooms                7035 non-null   object
#  7   Has pool                7035 non-null   object
#  8   Cleaning Fee            7035 non-null   int64
#  9   Extra Guest Fee         7035 non-null   int64
#  10  Average Daily Rate LTM  7035 non-null   int64
#  11  Occupancy Rate LTM      7035 non-null   int64
#  12  Annual Revenue LTM      7035 non-null   int64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 714.6+ KB

# %%
df2
# Out:
#                                      Listing URL Property Type   Latitude  \
# 0                  http://airbnb.com/rooms/61745   Entire Home  33.519190
# 1                 http://airbnb.com/rooms/122773   Entire Home  33.474000
# 2                 http://airbnb.com/rooms/135612         Condo  33.596690
# 3                 http://airbnb.com/rooms/241046  Private Room  33.558070
# 4                 http://airbnb.com/rooms/242595  Private Room  33.529380
# ...                                          ...           ...        ...
# 7030  http://airbnb.com/rooms/958723972133502202   Entire Home  33.471815
# 7031  http://airbnb.com/rooms/958777577132565108   Entire Home  33.383970
# 7032  http://airbnb.com/rooms/959114708267573468   Entire Home  33.384001
# 7033  http://airbnb.com/rooms/960401395602956462   Entire Home  33.384169
# 7034  http://airbnb.com/rooms/960498777199501262  Private Room  33.474211
#
#        Longitude  Star Rating  Number of Active Days Bedrooms Has pool  \
# 0    -112.073470          4.2                      3        3        t
# 1    -112.064000          4.9                    361        1        f
# 2    -111.987710          5.0                    135        1        t
# 3    -112.094420          4.9                    367        1        t
# 4    -112.096390          4.8                    145        1        t
# ...          ...          ...                    ...      ...      ...
# 7030 -112.051348          0.0                     13        2        t
# 7031 -112.012160          0.0                     14   Studio        t
# 7032 -112.166790          0.0                     14        4        t
# 7033 -112.012267          0.0                     14   Studio        t
# 7034 -112.017457          0.0                     14        1        f
#
#       Cleaning Fee  Extra Guest Fee  Average Daily Rate LTM  \
# 0              350                0                     402
# 1                0                0                     106
# 2              175                0                      92
# 3               20                0                      61
# 4                0               10                      42
# ...            ...              ...                     ...
# 7030             0                0                     147
# 7031             0                0                      59
# 7032             0                0                     185
# 7033             0                0                      59
# 7034             0                0                      41
#
#       Occupancy Rate LTM  Annual Revenue LTM
# 0                     40               58804
# 1                    100               38796
# 2                     57               21090
# 3                     72               18249
# 4                     64                9839
# ...                  ...                 ...
# 7030                 100               53802
# 7031                 100               21594
# 7032                 100               67710
# 7033                 100               21594
# 7034                  26                3895
#
# [7035 rows x 13 columns]

# %%
df2['Bedrooms'].unique()
# Out:
# array(['3', '1', '5', '8', '4', '2', 'Studio', '9', '6', '0', '10', '7',
#        '11'], dtype=object)

# %%
df2['Bedrooms'] = df2['Bedrooms'].replace('Studio', '12')
df2['Bedrooms'].unique()
# Out:
# array(['3', '1', '5', '8', '4', '2', '12', '9', '6', '0', '10', '7', '11'],
#       dtype=object)

# %%
df2['Bedrooms'] = df2['Bedrooms'].astype('int64')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7035 entries, 0 to 7034
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Listing URL             7035 non-null   object
#  1   Property Type           7035 non-null   object
#  2   Latitude                7035 non-null   float64
#  3   Longitude               7035 non-null   float64
#  4   Star Rating             7035 non-null   float64
#  5   Number of Active Days   7035 non-null   int64
#  6   Bedrooms                7035 non-null   int64
#  7   Has pool                7035 non-null   object
#  8   Cleaning Fee            7035 non-null   int64
#  9   Extra Guest Fee         7035 non-null   int64
#  10  Average Daily Rate LTM  7035 non-null   int64
#  11  Occupancy Rate LTM      7035 non-null   int64
#  12  Annual Revenue LTM      7035 non-null   int64
# dtypes: float64(3), int64(7), object(3)
# memory usage: 714.6+ KB

# %%
merged_df = x.merge(df2, on=['Latitude', 'Longitude'], how='inner')

# %%
merged_df
# Out:
# Empty DataFrame
# Columns: [List Number, Agency Name, Agency Phone, Listing Agent, Selling Agency, Selling Agent, Dwelling Type, List Date, Close of Escrow Date, Under Contract Date, Status, Status Change Date, Original List Price, List Price, Sold Price, Price/SqFt, Map Code/Grid, House Number, Compass, Street Name, St Suffix, City/Town Code, State/Province, County Code, Country, Zip Code, Latitude, Longitude, Approx SQFT, Bedrooms Plus, Year Built, Buyer Broker $/%, Buyer/Broker, Subagents, Variable Commission, Bedrooms_x, # Bathrooms, # of Interior Levels, Exterior Stories, Source Apx Lot SqFt, Pool, Taxes, Tax Year, Legal Description (Abbrev), Public Remarks, Assessor Number, Directions, Ownr/Occ Name - DND2, Builder Name, mod_timestamp, Source of SqFt, Tax Municipality, Auction, Horses, Ownership, Type, Elementary School, Jr. High School, High School, Zip4, Comp to Subagent, Comp to Buyer Broker, Approx Lot SqFt, Assessor's Book #, Assessor's Map #, Assessor's Parcel #, Off Market Date, Cross Street, Subdivision, Dwelling Styles, Approx Lot Acres, Photo URL, Days on Market, Features, Listing URL, Property Type, Star Rating, Number of Active Days, Bedrooms_y, Has pool, Cleaning Fee, Extra Guest Fee, Average Daily Rate LTM, Occupancy Rate LTM, Annual Revenue LTM]
# Index: []
#
# [0 rows x 85 columns]

# %%
merged_df_lat = x.merge(df2, on=['Latitude'], how='inner')
merged_df_lat
# Out:
#      List Number                                        Agency Name  \
# 0        6589926                             DeLex Realty (dele001)
# 1        6584262  Russ Lyon Sotheby's International Realty (LYON27)
# 2        6584262  Russ Lyon Sotheby's International Realty (LYON27)
# 3        6578874                 My Home Group Real Estate (myhg02)
# 4        6583548                    Libertas Real Estate (liber004)
# ..           ...                                                ...
# 139      5019569     Keller Williams Realty Sonoran Living (kwsl02)
# 140      5106020  Better Homes & Gardens Real Estate SJ Fowler (...
# 141      5105763                       US Preferred Realty (uspr01)
# 142      5116775                    Wise Choice Properties (wcpr01)
# 143      5095379           Keller Williams Integrity First (kwif10)
#
#        Agency Phone       Listing Agent  \
# 0               NaN       Carole Wilson
# 1    (480) 315-1575       Chauncey Beck
# 2    (480) 315-1575       Chauncey Beck
# 3    (480) 685-2760  Patrick Lee Kaiser
# 4    (623) 271-9742     Jeremy Jennings
# ..              ...                 ...
# 139  (480) 948-3338        Katie Baccus
# 140  (480) 649-3536       Linda Moening
# 141  (480) 756-9922           Gary Chen
# 142  (602) 687-8792     James Carpenter
# 143  (480) 354-7344         Kenny Klaus
#
#                                      Selling Agency    Selling Agent  \
# 0                                               NaN              NaN
# 1                                               NaN              NaN
# 2                                               NaN              NaN
# 3                                               NaN              NaN
# 4                                               NaN              NaN
# ..                                              ...              ...
# 139  Keller Williams Realty Sonoran Living (kwsl02)     Katie Baccus
# 140             Just Referrals Real Estate (wsrr01)  Elliot L Barkan
# 141         Keller Williams Arizona Realty (kwaz10)   Kathleen Ammon
# 142                        West USA Realty (wusa06)      Asa Hemberg
# 143                              HomeSmart (cril03)       Adam Cohen
#
#                 Dwelling Type   List Date Close of Escrow Date  \
# 0    Single Family - Detached  2023-08-08                  NaN
# 1    Single Family - Detached  2023-07-25                  NaN
# 2    Single Family - Detached  2023-07-25                  NaN
# 3    Single Family - Detached  2023-07-08                  NaN
# 4    Single Family - Detached  2023-07-22                  NaN
# ..                        ...         ...                  ...
# 139      Apartment Style/Flat  2013-10-23           2014-06-24
# 140  Single Family - Detached  2014-04-25           2014-06-26
# 141  Single Family - Detached  2014-04-25           2014-06-24
# 142  Single Family - Detached  2014-05-16           2014-06-27
# 143  Single Family - Detached  2014-04-04           2014-06-30
#
#     Under Contract Date  ... Longitude_y Star Rating  Number of Active Days  \
# 0                   NaN  ...  -112.05236         5.0                    195
# 1                   NaN  ...  -112.03348         5.0                    351
# 2                   NaN  ...  -112.05819         4.9                    151
# 3                   NaN  ...  -112.05049         5.0                    323
# 4                   NaN  ...  -112.07576         5.0                     44
# ..                  ...  ...         ...         ...                    ...
# 139          2014-05-12  ...  -112.01278         5.0                    295
# 140          2014-06-17  ...  -112.01316         5.0                     77
# 141          2014-06-06  ...  -111.96075         4.0                      4
# 142          2014-05-20  ...  -112.01587         5.0                      4
# 143          2014-05-27  ...  -112.00686         5.0                     85
#
#      Bedrooms_y  Has pool  Cleaning Fee Extra Guest Fee  \
# 0             2         t             0               0
# 1             1         f            50               0
# 2             2         f             0               0
# 3             2         f            20               0
# 4             4         f             0               0
# ..          ...       ...           ...             ...
# 139           1         f            65               0
# 140           1         t             0               0
# 141           1         t            90               0
# 142           4         t           180               0
# 143           1         t           125               0
#
#     Average Daily Rate LTM Occupancy Rate LTM Annual Revenue LTM
# 0                      122                 55              24560
# 1                       94                 55              21425
# 2                      100                 68              24888
# 3                      126                 65              30928
# 4                      366                 63              84396
# ..                     ...                ...                ...
# 139                     55                 48              10146
# 140                     94                 26               8946
# 141                    444                100             162504
# 142                    491                100             179706
# 143                     45                100              19161
#
# [144 rows x 86 columns]

# %%
merged_df_lat['Latitude']
# Out:
# 0      33.58146
# 1      33.47328
# 2      33.47328
# 3      33.59141
# 4      33.50717
#          ...
# 139    33.50555
# 140    33.38445
# 141    33.58696
# 142    33.47214
# 143    33.37771
# Name: Latitude, Length: 144, dtype: float64

# %%
merged_df_long = x.merge(df2, on=['Longitude'], how='inner')
merged_df_long
# Out:
#     List Number                               Agency Name    Agency Phone  \
# 0       6579754                        NORTH&CO. (nrtc01)  (602) 714-7000
# 1       6597498                        HomeSmart (cril01)  (602) 230-7600
# 2       6602869                        HomeSmart (cril16)  (623) 889-7100
# 3       6602177                  West USA Realty (wusa02)  (480) 948-5554
# 4       6571588                       eXp Realty (xpre01)  (888) 897-7821
# ..          ...                                       ...             ...
# 75      5105559             Domaine Real Estate (doma001)  (480) 688-3888
# 76      5108556        My Home Group Real Estate (myhg01)  (480) 685-2760
# 77      5108988  Keller Williams Realty Phoenix (kwrp001)  (480) 768-9333
# 78      5116775           Wise Choice Properties (wcpr01)  (602) 687-8792
# 79      5116775           Wise Choice Properties (wcpr01)  (602) 687-8792
#
#               Listing Agent                       Selling Agency  \
# 0        Michelle K Grening                                  NaN
# 1              Lisa A Dixon                                  NaN
# 2              April L Keys                                  NaN
# 3             AnaMarie Rigo                                  NaN
# 4               Aaron Remer                                  NaN
# ..                      ...                                  ...
# 75        Jerry A. Humphrey           Realty Executives (reax15)
# 76  Shawna Noel Scheinerman             West USA Realty (wusa05)
# 77              Carlie Back  Just Referrals Real Estate (wsrr01)
# 78          James Carpenter             West USA Realty (wusa06)
# 79          James Carpenter             West USA Realty (wusa06)
#
#         Selling Agent             Dwelling Type   List Date  \
# 0                 NaN  Single Family - Detached  2023-07-13
# 1                 NaN  Single Family - Detached  2023-08-25
# 2                 NaN      Apartment Style/Flat  2023-09-07
# 3                 NaN  Single Family - Detached  2023-09-07
# 4                 NaN  Single Family - Detached  2023-06-21
# ..                ...                       ...         ...
# 75      Mary E Murphy  Single Family - Detached  2014-04-23
# 76      Ciprian Jivcu  Single Family - Detached  2014-05-01
# 77  Ron Hollingsworth  Single Family - Detached  2014-05-01
# 78        Asa Hemberg  Single Family - Detached  2014-05-16
# 79        Asa Hemberg  Single Family - Detached  2014-05-16
#
#    Close of Escrow Date Under Contract Date  ... Latitude_y Star Rating  \
# 0                   NaN                 NaN  ...   33.55807         4.9
# 1                   NaN                 NaN  ...   33.36519         4.8
# 2                   NaN                 NaN  ...   33.46880         5.0
# 3                   NaN                 NaN  ...   33.49405         5.0
# 4                   NaN                 NaN  ...   33.50614         5.0
# ..                  ...                 ...  ...        ...         ...
# 75           2014-06-24          2014-05-03  ...   33.47072         5.0
# 76           2014-06-25          2014-05-13  ...   33.49439         5.0
# 77           2014-06-26          2014-05-26  ...   33.55425         4.6
# 78           2014-06-27          2014-05-20  ...   33.44879         5.0
# 79           2014-06-27          2014-05-20  ...   33.50463         4.9
#
#     Number of Active Days  Bedrooms_y  Has pool  Cleaning Fee Extra Guest Fee  \
# 0                     367           1         t            20               0
# 1                      46           1         f            43              15
# 2                       4           1         f             0               0
# 3                      84           2         f             0               0
# 4                     207           1         t             0               0
# ..                    ...         ...       ...           ...             ...
# 75                      4           3         f           250               0
# 76                     13           2         t             0               0
# 77                    183           3         f            90              10
# 78                    103           2         t           150               0
# 79                    184           1         f             0               0
#
#    Average Daily Rate LTM Occupancy Rate LTM Annual Revenue LTM
# 0                      61                 72              18249
# 1                      47                 34               6874
# 2                     100                100              36600
# 3                      75                 47              12902
# 4                     210                 66              50727
# ..                    ...                ...                ...
# 75                    425                100             155550
# 76                    173                 74              46848
# 77                    136                 83              45814
# 78                    126                 97              47932
# 79                    126                 70              32282
#
# [80 rows x 86 columns]

# %%
merged_df = x.merge(df2, on=['Latitude', 'Longitude'], how='outer')
merged_df
# Out:
#        List Number                          Agency Name    Agency Phone  \
# 0        6597146.0       W and Partners, LLC (wandp001)  (602) 828-5767
# 1        6586753.0          DRH Properties Inc (drhp01)  (480) 483-0006
# 2        6592065.0                   HomeSmart (cril01)  (602) 230-7600
# 3        6583021.0         Long Realty Company (long20)  (520) 439-3900
# 4        6564266.0  Symmetry Realty Brokerage (symm001)  (928) 779-5700
# ...            ...                                  ...             ...
# 15284          NaN                                  NaN             NaN
# 15285          NaN                                  NaN             NaN
# 15286          NaN                                  NaN             NaN
# 15287          NaN                                  NaN             NaN
# 15288          NaN                                  NaN             NaN
#
#            Listing Agent Selling Agency Selling Agent  \
# 0          Elijah Celaya            NaN           NaN
# 1      Stacey Vannasdale            NaN           NaN
# 2        Patricia Corbin            NaN           NaN
# 3       Jocelyn T Lawley            NaN           NaN
# 4             Deana Keck            NaN           NaN
# ...                  ...            ...           ...
# 15284                NaN            NaN           NaN
# 15285                NaN            NaN           NaN
# 15286                NaN            NaN           NaN
# 15287                NaN            NaN           NaN
# 15288                NaN            NaN           NaN
#
#                   Dwelling Type   List Date Close of Escrow Date  \
# 0      Single Family - Detached  2023-08-21                  NaN
# 1      Single Family - Detached  2023-07-31                  NaN
# 2          Apartment Style/Flat  2023-08-11                  NaN
# 3      Single Family - Detached  2023-07-21                  NaN
# 4                    Patio Home  2023-06-02                  NaN
# ...                         ...         ...                  ...
# 15284                       NaN         NaN                  NaN
# 15285                       NaN         NaN                  NaN
# 15286                       NaN         NaN                  NaN
# 15287                       NaN         NaN                  NaN
# 15288                       NaN         NaN                  NaN
#
#       Under Contract Date  ... Property Type Star Rating  \
# 0                     NaN  ...           NaN         NaN
# 1                     NaN  ...           NaN         NaN
# 2                     NaN  ...           NaN         NaN
# 3                     NaN  ...           NaN         NaN
# 4                     NaN  ...           NaN         NaN
# ...                   ...  ...           ...         ...
# 15284                 NaN  ...   Entire Home         0.0
# 15285                 NaN  ...   Entire Home         0.0
# 15286                 NaN  ...   Entire Home         0.0
# 15287                 NaN  ...   Entire Home         0.0
# 15288                 NaN  ...  Private Room         0.0
#
#        Number of Active Days  Bedrooms_y  Has pool  Cleaning Fee  \
# 0                        NaN         NaN       NaN           NaN
# 1                        NaN         NaN       NaN           NaN
# 2                        NaN         NaN       NaN           NaN
# 3                        NaN         NaN       NaN           NaN
# 4                        NaN         NaN       NaN           NaN
# ...                      ...         ...       ...           ...
# 15284                   13.0         2.0         t           0.0
# 15285                   14.0        12.0         t           0.0
# 15286                   14.0         4.0         t           0.0
# 15287                   14.0        12.0         t           0.0
# 15288                   14.0         1.0         f           0.0
#
#       Extra Guest Fee Average Daily Rate LTM Occupancy Rate LTM  \
# 0                 NaN                    NaN                NaN
# 1                 NaN                    NaN                NaN
# 2                 NaN                    NaN                NaN
# 3                 NaN                    NaN                NaN
# 4                 NaN                    NaN                NaN
# ...               ...                    ...                ...
# 15284             0.0                  147.0              100.0
# 15285             0.0                   59.0              100.0
# 15286             0.0                  185.0              100.0
# 15287             0.0                   59.0              100.0
# 15288             0.0                   41.0               26.0
#
#       Annual Revenue LTM
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 15284            53802.0
# 15285            21594.0
# 15286            67710.0
# 15287            21594.0
# 15288             3895.0
#
# [15289 rows x 85 columns]

# %% [markdown]
# ### We dont see any positive results here
# ### lets trunacate the Latitude and Logitude to 3 decimals values and proceed next

# %%
x['Latitude'] =x['Latitude'].round(3)
x['Longitude'] =x['Longitude'].round(3)

# %%
df2['Latitude'] =df2['Latitude'].round(3)
df2['Longitude'] =df2['Longitude'].round(3)

# %%
merged_df = x.merge(df2, on=['Latitude', 'Longitude','Bedrooms'], how='inner')
merged_df
# Out:
#      List Number                              Agency Name    Agency Phone  \
# 0        6592065                       HomeSmart (cril01)  (602) 230-7600
# 1        6519192       My Home Group Real Estate (myhg24)  (480) 685-2760
# 2        6582692                       NORTH&CO. (nrtc01)  (602) 714-7000
# 3        6595764                      eXp Realty (xpre08)  (888) 897-7821
# 4        6581466                Realty ONE Group (reog01)  (480) 315-1240
# ..           ...                                      ...             ...
# 255      5099171  Biltmore Lifestyles RE Company (brec01)  (602) 418-6145
# 256      5099171  Biltmore Lifestyles RE Company (brec01)  (602) 418-6145
# 257      5099171  Biltmore Lifestyles RE Company (brec01)  (602) 418-6145
# 258      5039691               Realty Executives (reax09)  (480) 948-9450
# 259      6453024                  Landsea Homes (laho001)  (480) 714-8080
#
#            Listing Agent                       Selling Agency   Selling Agent  \
# 0        Patricia Corbin                                  NaN             NaN
# 1        Cathy Piccinini                                  NaN             NaN
# 2        Sheryl Matuszak                                  NaN             NaN
# 3           Steven Brady                                  NaN             NaN
# 4           Josh Hintzen                                  NaN             NaN
# ..                   ...                                  ...             ...
# 255  Cynthia J Stockwell                   HomeSmart (cril11)  Greg M Gallese
# 256  Cynthia J Stockwell                   HomeSmart (cril11)  Greg M Gallese
# 257  Cynthia J Stockwell                   HomeSmart (cril11)  Greg M Gallese
# 258   Pamela E Thurnherr      Coldwell Banker Realty (cbrb02)      Cindy Neel
# 259       Mindy Perfette  Equity Arizona Real Estate (eazr01)  Terry Brubaker
#
#                 Dwelling Type   List Date Close of Escrow Date  \
# 0        Apartment Style/Flat  2023-08-11                  NaN
# 1    Single Family - Detached  2023-02-10                  NaN
# 2    Single Family - Detached  2023-07-20                  NaN
# 3                   Townhouse  2023-08-22                  NaN
# 4    Single Family - Detached  2023-07-17                  NaN
# ..                        ...         ...                  ...
# 255      Apartment Style/Flat  2014-03-23           2014-06-24
# 256      Apartment Style/Flat  2014-03-23           2014-06-24
# 257      Apartment Style/Flat  2014-03-23           2014-06-24
# 258  Single Family - Detached  2013-12-05           2014-06-24
# 259  Single Family - Detached  2022-08-20           2022-11-16
#
#     Under Contract Date  ...                                 Listing URL  \
# 0                   NaN  ...  http://airbnb.com/rooms/734881649522242825
# 1                   NaN  ...            http://airbnb.com/rooms/15520295
# 2                   NaN  ...  http://airbnb.com/rooms/681852339181209422
# 3                   NaN  ...  http://airbnb.com/rooms/934734094325147856
# 4                   NaN  ...  http://airbnb.com/rooms/922577070943220448
# ..                  ...  ...                                         ...
# 255          2014-06-03  ...  http://airbnb.com/rooms/656532429347419004
# 256          2014-06-03  ...  http://airbnb.com/rooms/683312737425624814
# 257          2014-06-03  ...  http://airbnb.com/rooms/860340542265828915
# 258          2014-05-17  ...  http://airbnb.com/rooms/864887600656291733
# 259          2022-09-30  ...  http://airbnb.com/rooms/780699509156407612
#
#     Property Type  Star Rating  Number of Active Days  Has pool  Cleaning Fee  \
# 0           Condo          0.0                     50         t             0
# 1     Entire Home          4.9                    260         t            25
# 2     Entire Home          4.8                    214         t             0
# 3     Entire Home          0.0                     14         t             0
# 4     Entire Home          0.0                     14         t             0
# ..            ...          ...                    ...       ...           ...
# 255         Condo          4.7                     31         t             0
# 256         Condo          4.8                     58         t             0
# 257         Condo          5.0                     62         t             0
# 258   Entire Home          4.8                     67         t             0
# 259   Entire Home          5.0                    187         f             0
#
#     Extra Guest Fee Average Daily Rate LTM Occupancy Rate LTM  \
# 0                 0                    144                 67
# 1                 0                    199                100
# 2                 0                    298                 26
# 3                 0                    106                 17
# 4                 0                    628                 69
# ..              ...                    ...                ...
# 255               0                    209                 89
# 256               0                    169                 56
# 257               0                     89                 64
# 258               0                    362                 86
# 259               0                    133                 60
#
#     Annual Revenue LTM
# 0                35312
# 1                77163
# 2                28358
# 3                 6588
# 4               158583
# ..                 ...
# 255              68076
# 256              34637
# 257              20850
# 258             113941
# 259              29208
#
# [260 rows x 84 columns]

# %%
merged_df.to_csv('250 prop.csv')

# %%
desired_latitude = 33.312
desired_longitude= -111.841
result = x[x['Longitude'] == desired_latitude]
result
# Out:
# Empty DataFrame
# Columns: [List Number, Agency Name, Agency Phone, Listing Agent, Selling Agency, Selling Agent, Dwelling Type, List Date, Close of Escrow Date, Under Contract Date, Status, Status Change Date, Original List Price, List Price, Sold Price, Price/SqFt, Map Code/Grid, House Number, Compass, Street Name, St Suffix, City/Town Code, State/Province, County Code, Country, Zip Code, Latitude, Longitude, Approx SQFT, Bedrooms Plus, Year Built, Buyer Broker $/%, Buyer/Broker, Subagents, Variable Commission, Bedrooms, # Bathrooms, # of Interior Levels, Exterior Stories, Source Apx Lot SqFt, Pool, Taxes, Tax Year, Legal Description (Abbrev), Public Remarks, Assessor Number, Directions, Ownr/Occ Name - DND2, Builder Name, mod_timestamp, Source of SqFt, Tax Municipality, Auction, Horses, Ownership, Type, Elementary School, Jr. High School, High School, Zip4, Comp to Subagent, Comp to Buyer Broker, Approx Lot SqFt, Assessor's Book #, Assessor's Map #, Assessor's Parcel #, Off Market Date, Cross Street, Subdivision, Dwelling Styles, Approx Lot Acres, Photo URL, Days on Market, Features]
# Index: []
#
# [0 rows x 74 columns]
